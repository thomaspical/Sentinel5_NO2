# %% [markdown]
# # Etude journalière de la concentration de NO2

# %%
import pandas as pd
import numpy as np
import os

import plotly.graph_objects as go
import plotly.express as px

# %%
#Config
path="datas_sentinel5/"

# %%
df_NO2=pd.DataFrame()

ls=[i for i in os.listdir(path+"archives") if os.path.isfile(os.path.join(path+"archives",i)) and 'archived' in i]
for elem in ls:
    df_NO2_new=pd.read_csv(path+"archives/"+elem, index_col=0)
    df_NO2_new=df_NO2_new.replace("","Undefined")
    df_NO2=pd.concat([df_NO2, df_NO2_new], axis=0)
    
df_NO2=df_NO2.reset_index(drop=True)
#Re-arranging date
df_NO2=df_NO2.rename(columns={"day_mean":"day"})
df_NO2["date"]=pd.to_datetime(df_NO2[["year","month","day"]])
df_NO2=df_NO2.drop(columns=["year","month","day"])

# %%
#df_NO2.loc[:,["cc_departement","cc_region","cc_ville"]]=df_NO2.loc[:,["cc_departement","cc_region","cc_ville"]].fillna("Undefined")

# %%
df_NO2["calcul"]=df_NO2.NO2*df_NO2.counter

# %%
#Evolution of pollution for some countries
df_NO2_group=df_NO2.groupby(["cc_pays",df_NO2.date.dt.year,df_NO2.date.dt.month,df_NO2.date.dt.day]).agg({'counter':'sum','calcul':'sum'})
df_NO2_group["NO2"]=df_NO2_group.calcul/df_NO2_group.counter

# %%
df_NO2_group["date"]=pd.to_datetime(df_NO2_group.index.get_level_values(1).astype(str) + df_NO2_group.index.get_level_values(2).astype(str) + df_NO2_group.index.get_level_values(3).astype(str), format="%Y%m%d")
df_NO2_group["cc_pays"]=df_NO2_group.index.get_level_values(0).astype(str)

# %%
ls=["FR","CN","IT","JP","DE","IN"]
fig = px.line(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_pays]], y="NO2", x="date", color="cc_pays", title="NO2 Evolution for countries", render_mode="webgl")
fig.show()
# Out:
# <div>
#
#
#             <div id="db580025-b8f6-4e66-b8fb-820a742a98aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db580025-b8f6-4e66-b8fb-820a742a98aa")) {
#                     Plotly.newPlot(
#                         'db580025-b8f6-4e66-b8fb-820a742a98aa',
# ...

# %%
ls=["FR","CN","IT","JP","DE","IN"]
fig = px.line(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_pays]], y="counter", x="date", color="cc_pays", title="Observations evolution for countries", render_mode="webgl")
fig.show()
# Out:
# <div>
#
#
#             <div id="2278d802-7d77-4f7b-840b-e44790e937fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2278d802-7d77-4f7b-840b-e44790e937fd")) {
#                     Plotly.newPlot(
#                         '2278d802-7d77-4f7b-840b-e44790e937fd',
# ...

# %%
fig = px.box(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_pays]], x="cc_pays", y="counter", color="cc_pays",points="all")
fig.show()
# Out:
# <div>
#
#
#             <div id="8fe90b6c-5aa5-4d15-8689-83ae79d2ac7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8fe90b6c-5aa5-4d15-8689-83ae79d2ac7b")) {
#                     Plotly.newPlot(
#                         '8fe90b6c-5aa5-4d15-8689-83ae79d2ac7b',
# ...

# %%
#Pollution evolution for french regions
df_NO2_group=df_NO2.groupby(["cc_region",df_NO2.date.dt.year,df_NO2.date.dt.month,df_NO2.date.dt.day]).agg({'counter':'sum','calcul':'sum'})
df_NO2_group["NO2"]=df_NO2_group.calcul/df_NO2_group.counter

# %%
df_NO2_group["date"]=pd.to_datetime(df_NO2_group.index.get_level_values(1).astype(str) + df_NO2_group.index.get_level_values(2).astype(str) + df_NO2_group.index.get_level_values(3).astype(str), format="%Y%m%d")
df_NO2_group["cc_region"]=df_NO2_group.index.get_level_values(0).astype(str)

# %%
ls=["Ile-de-France","Nord-Pas-de-Calais","Pyongyang","Hubei", "New York","Beijing", "Berlin"]
fig = px.line(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_region]], y="NO2", x="date", color="cc_region", title="NO2 Evolution for regions", render_mode="webgl")
fig.show()
# Out:
# <div>
#
#
#             <div id="faebdee3-930a-4c44-9496-38a60f510def" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("faebdee3-930a-4c44-9496-38a60f510def")) {
#                     Plotly.newPlot(
#                         'faebdee3-930a-4c44-9496-38a60f510def',
# ...

# %%
fig = px.line(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_region]], y="counter", x="date", color="cc_region", title="Observations evolution for regions", render_mode="webgl")
fig.show()
# Out:
# <div>
#
#
#             <div id="c4cc18d6-6f32-4f48-87c9-9185494b58d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c4cc18d6-6f32-4f48-87c9-9185494b58d5")) {
#                     Plotly.newPlot(
#                         'c4cc18d6-6f32-4f48-87c9-9185494b58d5',
# ...

# %%
fig = px.box(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_region]], x="cc_region", y="counter", color="cc_region",points="all")
fig.show()
# Out:
# <div>
#
#
#             <div id="9f19e249-ad78-47f3-803a-20468b14e6ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f19e249-ad78-47f3-803a-20468b14e6ad")) {
#                     Plotly.newPlot(
#                         '9f19e249-ad78-47f3-803a-20468b14e6ad',
# ...

# %%
#Worldwide sans les oceans 
df_NO2_group=df_NO2[(df_NO2.cc_pays != "Undefined") & (df_NO2.cc_departement != "Undefined") & (df_NO2.cc_region != "Undefined")].groupby([df_NO2.date.dt.year,df_NO2.date.dt.month,df_NO2.date.dt.day]).agg({'counter':'sum','calcul':'sum'})
df_NO2_group["NO2"]=df_NO2_group.calcul/df_NO2_group.counter
df_NO2_group["date"]=pd.to_datetime(df_NO2_group.index.get_level_values(0).astype(str) + df_NO2_group.index.get_level_values(1).astype(str) + df_NO2_group.index.get_level_values(2).astype(str), format="%Y%m%d")

# %%
fig = px.line(df_NO2_group, y="NO2", x="date", render_mode="webgl", title="Global average NO2 level outside the oceans")
fig.show()
# Out:
# <div>
#
#
#             <div id="07b93961-6f5a-46fb-8e8d-70ba9a31b6f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07b93961-6f5a-46fb-8e8d-70ba9a31b6f7")) {
#                     Plotly.newPlot(
#                         '07b93961-6f5a-46fb-8e8d-70ba9a31b6f7',
# ...

# %%
fig = px.line(df_NO2_group, y="counter", x="date", render_mode="webgl", title="Observations evolutions at defined places")
fig.show()
# Out:
# <div>
#
#
#             <div id="7213787b-1301-4f67-af61-7378e55876de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7213787b-1301-4f67-af61-7378e55876de")) {
#                     Plotly.newPlot(
#                         '7213787b-1301-4f67-af61-7378e55876de',
# ...

# %%
fig = px.line(df_NO2_group, y="counter", x="date", render_mode="webgl", title="Observations evolutions at defined places")
fig.show()
# Out:
# <div>
#
#
#             <div id="1950f1c1-4bdb-487c-9a76-cf166e5e177d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1950f1c1-4bdb-487c-9a76-cf166e5e177d")) {
#                     Plotly.newPlot(
#                         '1950f1c1-4bdb-487c-9a76-cf166e5e177d',
# ...

# %%
fig = px.box(df_NO2_group, y="counter", points="all")
fig.show()
# Out:
# <div>
#
#
#             <div id="0715f1ac-d92f-446c-8f3b-baee7e290a4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0715f1ac-d92f-446c-8f3b-baee7e290a4e")) {
#                     Plotly.newPlot(
#                         '0715f1ac-d92f-446c-8f3b-baee7e290a4e',
# ...

# %% [markdown]
# # Etude Mensuelle

# %%
df_NO2
# Out:
#          week cc_pays cc_departement           cc_region             cc_ville  \
# 0           8      AD            NaN             Canillo              Canillo
# 1           8      AD            NaN             Canillo            El Tarter
# 2           8      AD            NaN              Encamp               Encamp
# 3           8      AD            NaN              Encamp       Pas de la Casa
# 4           8      AD            NaN  Escaldes-Engordany         les Escaldes
# ...       ...     ...            ...                 ...                  ...
# 3918884    15      ZW      Undefined            Midlands               Kwekwe
# 3918885    15      ZW      Undefined            Midlands             Shangani
# 3918886    15      ZW      Undefined           Undefined             Chirundu
# 3918887    15      ZW      Undefined           Undefined  Dorowa Mining Lease
# 3918888    15      ZW      Undefined           Undefined           Raffingora
#
# ...

# %%
#Pollution evolution for french regions
df_NO2_group=df_NO2.groupby(["cc_region",df_NO2.date.dt.year,df_NO2.date.dt.month]).agg({'counter':'sum','calcul':'sum'})
df_NO2_group["NO2"]=df_NO2_group.calcul/df_NO2_group.counter

# %%
df_NO2_group["date"]=pd.to_datetime(df_NO2_group.index.get_level_values(1).astype(str) + df_NO2_group.index.get_level_values(2).astype(str) +"01", format="%Y%m%d")
df_NO2_group["cc_region"]=df_NO2_group.index.get_level_values(0).astype(str)

# %%
ls=["Ile-de-France","Nord-Pas-de-Calais","Pyongyang","Hubei", "New York","Beijing", "Berlin"]
fig = px.line(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_region]], y="NO2", x="date", color="cc_region", title="NO2 Evolution for regions", render_mode="webgl")
fig.show()
# Out:
# <div>
#
#
#             <div id="88fb5b12-d880-4756-8f8c-619f7d28ada7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88fb5b12-d880-4756-8f8c-619f7d28ada7")) {
#                     Plotly.newPlot(
#                         '88fb5b12-d880-4756-8f8c-619f7d28ada7',
# ...

# %%
fig = px.line(df_NO2_group[[elem in ls for elem in df_NO2_group.cc_region]], y="counter", x="date", color="cc_region", title="Observations evolution for regions", render_mode="webgl")
fig.show()
# Out:
# <div>
#
#
#             <div id="41226946-8e72-4a74-9fa1-57546ef81c8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41226946-8e72-4a74-9fa1-57546ef81c8f")) {
#                     Plotly.newPlot(
#                         '41226946-8e72-4a74-9fa1-57546ef81c8f',
# ...
